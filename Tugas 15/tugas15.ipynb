# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('Data_Tanaman_Padi_Sumatera_version_1.csv')
df
# Out:
#     Provinsi  Tahun    Produksi  Luas Panen  Curah hujan  Kelembapan  \
# 0       Aceh   1993  1329536.00   323589.00       1627.0       82.00
# 1       Aceh   1994  1299699.00   329041.00       1521.0       82.12
# 2       Aceh   1995  1382905.00   339253.00       1476.0       82.72
# 3       Aceh   1996  1419128.00   348223.00       1557.0       83.00
# 4       Aceh   1997  1368074.00   337561.00       1339.0       82.46
# ..       ...    ...         ...         ...          ...         ...
# 219  Lampung   2016  3831923.00   390799.00       2317.6       79.40
# 220  Lampung   2017  4090654.00   396559.00       1825.1       77.04
# 221  Lampung   2018  2488641.91   511940.93       1385.8       76.05
# 222  Lampung   2019  2164089.33   464103.42       1706.4       78.03
# 223  Lampung   2020  2604913.29   545149.05       2211.3       75.80
#
#      Suhu rata-rata
# 0             26.06
# 1             26.92
# 2             26.27
# 3             26.08
# 4             26.31
# ...

# %% [markdown]
# Dari dokumen csv yang sudah didapat kita dapat menganalisis mengenai data tentang produksi tanaman padi di provinsi yang berada di daerah Sumatera dari tahun 1993 - 2020, dengan memperkirakan dari luas panen dan keadaan cuaca yang dapat mendukung prosesnya yaitu curah hujan, kelembapan dan suhu rata rata untuk mengeringkan padi secara alami.
# - Untuk mengetahui seberapa berpengaruhnya kondisi cuaca dengan produksi padi, kita dapat menganalisis di bagian curah hujan, kelembapan dan suhu rata-rata untuk proses penjemuran. dengan bantuan visualisasi dengan scatter plot dengan melihat titik titik yang mewakili data kita dapat melihat perbedaan produksi di beberapa tahun dengan luas daerah yang dipanen di setiap provinsinya.
# - untuk mengetahui jumlah produksi paling tinggi atau paling rendah di antara rentang waktunya maka dapat dilakukan perbandingan dengan bantuan bar chart agar terlehat berbeda atau dengan pie chart agar muncul persenan perbedaannya.
# - dari data ini juga kita dapat menganalisis apakah luas panen dapat berpengaruh dengan produksi yang dapat di lakukan tiap tahunnya dari berbagai provinsi di daerah sumatera. dengan bantuan visualisasi dapat mempermudah kita untuk menganalis provinsi mana yang memiliki curah hujan yang tinggi, luas panen yang paling besar, provinsi dengan jumlah produksi paling tinggi dan yang lainnya dengan bantuan scatter plot, bar chart atau pie chart.
