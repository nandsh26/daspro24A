# %% [markdown]
# <b>Project Data Pengunjung Wahana</b><br>
# Sampel 1000 data pengunjung wahana dengan 10 parameter<br>
# <ol>
#     <li>Usia : 10 - 59</li>
#     <li>Gender : L / P</li>
#     <li>Wahana : Roller Coaster, Bianglala, Rumah Hantu, Kora-kora</li>
#     <li>Asal Kota : Jakarta, Bandung, Surabaya, Yogyakarta</li>
#     <li>Jenis Tiket : Reguler, VIP, Promo</li>
#     <li>Waktu Kunjungan : Pagi, Siang, Sore, Malam</li>
#     <li>Cuaca : Cerah, Mendung, Hujan</li>
#     <li>Antrian : Pendek, Sedang, Panjang</li>
#     <li>Metode Bayar : Cash, E-Money, Kartu Kredit</li>
#     <li>Kepuasan : Puas, Cukup, Tidak Puas</li>
# </ol>

# %%
import numpy as np
import pandas as pd

nData = 1000

usia = np.random.randint(10, 60, size=nData)
gender = np.random.choice(['L', 'P'], size=nData)
wahana = np.random.choice(['Roller Coaster', 'Bianglala', 'Rumah Hantu', 'Kora-kora'], size=nData)
asalKota = np.random.choice(['Jakarta', 'Bandung', 'Surabaya', 'Yogyakarta'], size=nData)
jenisTiket = np.random.choice(['Reguler', 'VIP', 'Promo'], size=n_data)
waktuKunjungan = np.random.choice(['Pagi', 'Siang', 'Sore', 'Malam'], size=nData)
cuaca = np.random.choice(['Cerah', 'Mendung', 'Hujan'], size=nData)
antrian = np.random.choice(['Pendek', 'Sedang', 'Panjang'], size=nData)
metodeBayar = np.random.choice(['Cash', 'E-Money', 'Kartu Kredit'], size=nData)
kepuasan = np.random.choice(['Puas', 'Cukup', 'Tidak Puas'], size=nData)

df = pd.DataFrame({
    'Usia': usia,
    'Gender': gender,
    'Wahana': wahana,
    'Asal Kota': asalKota,
    'Jenis Tiket': jenisTiket,
    'Waktu Kunjungan': waktuKunjungan,
    'Cuaca': cuaca,
    'Antrian': antrian,
    'Metode Bayar': metodeBayar,
    'Kepuasan': kepuasan
})

print(df.info())

print(f"Usia pengunjung termuda: {df.Usia.min()}")
print(f"Usia pengunjung tertua: {df.Usia.max()}")

jmlL = df[df['Gender'] == 'L']
jmlP = df[df['Gender'] == 'P']
print(f"Jumlah pengunjung laki-laki: {jmlL.size / 10}")
print(f"Jumlah pengunjung perempuan: {jmlP.size / 10}")

rc = df[df['Wahana'] == 'Roller Coaster']
bl = df[df['Wahana'] == 'Bianglala']
rh = df[df['Wahana'] == 'Rumah Hantu']
kk = df[df['Wahana'] == 'Kora-kora']
print(f"Jumlah pengunjung Roller Coaster: {rc.size / 10}")
print(f"Jumlah pengunjung Bianglala     : {bl.size / 10}")
print(f"Jumlah pengunjung Rumah Hantu   : {rh.size / 10}")
print(f"Jumlah pengunjung Kora-kora     : {kk.size / 10}")

jakarta = df[df['Asal Kota'] == 'Jakarta']
bandung = df[df['Asal Kota'] == 'Bandung']
surabaya = df[df['Asal Kota'] == 'Surabaya']
yogyakarta = df[df['Asal Kota'] == 'Yogyakarta']
print(f"Jumlah pengunjung dari Jakarta   : {jakarta.size / 10}")
print(f"Jumlah pengunjung dari Bandung   : {bandung.size / 10}")
print(f"Jumlah pengunjung dari Surabaya  : {surabaya.size / 10}")
print(f"Jumlah pengunjung dari Yogyakarta: {yogyakarta.size / 10}")

vip = df[df['Jenis Tiket'] == 'VIP']
reguler = df[df['Jenis Tiket'] == 'Reguler']
promo = df[df['Jenis Tiket'] == 'Promo']
print(f"Jumlah pemegang tiket VIP    : {vip.size / 10}")
print(f"Jumlah pemegang tiket Reguler: {reguler.size / 10}")
print(f"Jumlah pemegang tiket Promo  : {promo.size / 10}")

sore = df[df['Waktu Kunjungan'] == 'Sore']
print(f"Jumlah pengunjung di sore hari: {sore.size / 10}")

cerah = df[df['Cuaca'] == 'Cerah']
print(f"Jumlah pengunjung saat cuaca cerah: {cerah.size / 10}")

antriPanjang = df[df['Antrian'] == 'Panjang']
print(f"Jumlah antrian panjang: {antriPanjang.size / 10}")

cash = df[df['Metode Bayar'] == 'Cash']
emoney = df[df['Metode Bayar'] == 'E-Money']
cc = df[df['Metode Bayar'] == 'Kartu Kredit']
print(f"Jumlah pembayaran dengan Cash        : {cash.size / 10}")
print(f"Jumlah pembayaran dengan E-Money     : {emoney.size / 10}")
print(f"Jumlah pembayaran dengan Kartu Kredit: {cc.size / 10}")

puas = df[df['Kepuasan'] == 'Puas']
tidakPuas = df[df['Kepuasan'] == 'Tidak Puas']
cukup = df[df['Kepuasan'] == 'Cukup']
print(f"Jumlah pengunjung puas      : {puas.size / 10}")
print(f"Jumlah pengunjung tidak puas: {tidakPuas.size / 10}")
print(f"Jumlah pengunjung cukup     : {cukup.size / 10}")

df.to_csv('dataPengunjungWahana.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Usia             1000 non-null   int32
#  1   Gender           1000 non-null   object
#  2   Wahana           1000 non-null   object
#  3   Asal Kota        1000 non-null   object
#  4   Jenis Tiket      1000 non-null   object
#  5   Waktu Kunjungan  1000 non-null   object
#  6   Cuaca            1000 non-null   object
#  7   Antrian          1000 non-null   object
#  8   Metode Bayar     1000 non-null   object
#  9   Kepuasan         1000 non-null   object
# dtypes: int32(1), object(9)
# memory usage: 74.3+ KB
# None
# Usia pengunjung termuda: 10
# Usia pengunjung tertua: 59
# Jumlah pengunjung laki-laki: 524.0
# Jumlah pengunjung perempuan: 476.0
# Jumlah pengunjung Roller Coaster: 220.0
# Jumlah pengunjung Bianglala     : 268.0
# Jumlah pengunjung Rumah Hantu   : 241.0
# ...
